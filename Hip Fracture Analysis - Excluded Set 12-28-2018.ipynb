# %%
import pandas as pd 
import seaborn as sns 
import numpy as np
import scipy as sp

# %%
# Importing the Datasets 

df1 = pd.read_csv('Round1.csv')
df2 = pd.read_csv('Round2.csv')
df3 = pd.read_csv('Round3.csv')
df4 = pd.read_csv('Round4.csv')
df5 = pd.read_csv('Round5.csv')
df6 = pd.read_csv('Round6.csv')
df7 = pd.read_csv('Round7.csv')

# %%
# Merging the Datasets 

mergedset1 = pd.merge(df1, df2, on='spid',how='left')
mergedset2 = pd.merge(mergedset1,df3,on='spid',how='left')
mergedset3 = pd.merge(mergedset2,df4,on='spid',how='left')
mergedset4 = pd.merge(mergedset3,df5,on='spid',how='left')
mergedset5 = pd.merge(mergedset4,df6,on='spid',how='left')
mergedset_final = pd.merge(mergedset5,df7,on='spid',how='left')

# %%
hip_fracture_study = mergedset_final

# %%
hip_fracture_study = hip_fracture_study.replace('-1 Inapplicable',np.NaN)
hip_fracture_study = hip_fracture_study.replace('-9 Missing',np.NaN)
hip_fracture_study = hip_fracture_study.replace('-7 RF',np.NaN)
hip_fracture_study = hip_fracture_study.replace('-8 DK',np.NaN)
hip_fracture_study = hip_fracture_study.replace('.',np.NaN)

# %%
# Creating a Variable Representing "Working Status" - If Patients Work for Pay or Volunteer HKF_Work_Vol = 1 else HKF_Work_Vol = 0

conditions = [(hip_fracture_study['pa1workfrpay'] == '1 YES'), (hip_fracture_study['pa1workfrpay'] == '2 NO')]
choices = [1, 0]
hip_fracture_study['pa1workfrpay'] = np.select(conditions, choices)

conditions = [(hip_fracture_study['pa1voltrwork'] == '1 YES') , (hip_fracture_study['pa1voltrwork'] == '2 NO')]
choices = [1, 0]
hip_fracture_study['pa1voltrwork'] = np.select(conditions, choices)

hip_fracture_study['HKF_Work_Vol'] = hip_fracture_study['pa1voltrwork']+hip_fracture_study['pa1workfrpay']
                                                                                                             
conditions = [(hip_fracture_study['HKF_Work_Vol'] >= 1),(hip_fracture_study['HKF_Work_Vol'] == 0)]
choices = [1, 0]
hip_fracture_study['HKF_Work_Vol'] = np.select(conditions, choices)

# %%
# Converting the Imputed Income Values Round 1 - Round 3 from pd.Series to float

hip_fracture_study['ia1toincim1'] = hip_fracture_study['ia1toincim1'].astype(float)
hip_fracture_study['ia1toincim2'] = hip_fracture_study['ia1toincim2'].astype(float)
hip_fracture_study['ia1toincim3'] = hip_fracture_study['ia1toincim3'].astype(float)
hip_fracture_study['ia1toincim4'] = hip_fracture_study['ia1toincim4'].astype(float)
hip_fracture_study['ia1toincim5'] = hip_fracture_study['ia1toincim5'].astype(float)

hip_fracture_study['ia3toincim1'] = hip_fracture_study['ia3toincim1'].astype(float)
hip_fracture_study['ia3toincim2'] = hip_fracture_study['ia3toincim2'].astype(float)
hip_fracture_study['ia3toincim3'] = hip_fracture_study['ia3toincim3'].astype(float)
hip_fracture_study['ia3toincim4'] = hip_fracture_study['ia3toincim4'].astype(float)
hip_fracture_study['ia3toincim5'] = hip_fracture_study['ia3toincim5'].astype(float)

# %%
# Computing the Average Imputed Income for Round 1

hip_fracture_study['R1avg_income1-5'] = (hip_fracture_study['ia1toincim1']+hip_fracture_study['ia1toincim2']+hip_fracture_study['ia1toincim3']+hip_fracture_study['ia1toincim4']+hip_fracture_study['ia1toincim5'])/5

hip_fracture_study['R3avg_income1-5'] = (hip_fracture_study['ia3toincim1']+hip_fracture_study['ia3toincim2']+hip_fracture_study['ia3toincim3']+hip_fracture_study['ia3toincim4']+hip_fracture_study['ia3toincim5'])/5

hip_fracture_study['changeR1R3'] = (hip_fracture_study['R1avg_income1-5'] - hip_fracture_study['R3avg_income1-5'])

# %%
# Excluding Patients Prevented from Seeing Family by Health Before onset of Hip Fracture 

hip_fracture_study_pa1hlkepfvst = hip_fracture_study[hip_fracture_study.pa1hlkepfvst != '1 YES']

# %%
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa1hlkepfvst["hc2brokebon1"], 
                            columns=hip_fracture_study_pa1hlkepfvst["pa2hlkepfvst"],
                             margins=True)  
table1
# Out:
# pa2hlkepfvst  1 YES  2 NO   All
# hc2brokebon1
# 1 YES            15    46    61
# 2 NO            372  5036  5408
# All             387  5082  5469

# %%
# Excluding Patients Prevented from Seeing Family by Health Before onset of Hip Fracture 

hip_fracture_study_pa2hlkepfvst = hip_fracture_study[hip_fracture_study.pa2hlkepfvst != '1 YES']

# %%
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa1hlkepfvst["hc3brokebon1"], 
                            columns=hip_fracture_study_pa1hlkepfvst["pa3hlkepfvst"],
                             margins=True)  
table1
# Out:
# pa3hlkepfvst  1 YES  2 NO   All
# hc3brokebon1
# 1 YES            17    58    75
# 2 NO            338  4026  4364
# All             355  4084  4439

# %%
# Excluding Patients Prevented from Seeing Family by Health Before onset of Hip Fracture 

hip_fracture_study_pa3hlkepfvst = hip_fracture_study[hip_fracture_study.pa3hlkepfvst != '1 YES']

# %%
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa1hlkepfvst["hc4brokebon1"], 
                            columns=hip_fracture_study_pa1hlkepfvst["pa4hlkepfvst"],
                             margins=True)  
table1
# Out:
# pa4hlkepfvst  1 YES  2 NO   All
# hc4brokebon1
# 1 YES             8    40    48
# 2 NO            288  3372  3660
# All             296  3412  3708

# %%
# Excluding Patients Prevented from Seeing Family by Health Before onset of Hip Fracture 

hip_fracture_study_pa4hlkepfvst = hip_fracture_study[hip_fracture_study.pa4hlkepfvst != '1 YES']

# %%
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa1hlkepfvst["hc5brokebon1"], 
                            columns=hip_fracture_study_pa1hlkepfvst["pa5hlkepfvst"],
                             margins=True)  
table1
# Out:
# pa5hlkepfvst  1 YES  2 NO   All
# hc5brokebon1
# 1 YES             8    42    50
# 2 NO            260  3036  3296
# All             268  3078  3346

# %%
# Excluding Patients Prevented from Attending Religious Services by Health Before onset of Hip Fracture 

hip_fracture_study_pa1htkfrrlsr = hip_fracture_study[hip_fracture_study.pa1htkfrrlsr != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa1htkfrrlsr["hc2brokebon1"], 
                            columns=hip_fracture_study_pa1htkfrrlsr["pa2htkfrrlsr"],
                             margins=True)  
table1
# Out:
# pa2htkfrrlsr  1 YES  2 NO   All
# hc2brokebon1
# 1 YES            14    43    57
# 2 NO            464  4637  5101
# All             478  4680  5158

# %%
# Excluding Patients Prevented from Attending Religious Services by Health Before onset of Hip Fracture 

hip_fracture_study_pa2htkfrrlsr = hip_fracture_study[hip_fracture_study.pa2htkfrrlsr != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa2htkfrrlsr["hc3brokebon1"], 
                            columns=hip_fracture_study_pa2htkfrrlsr["pa3htkfrrlsr"],
                             margins=True)  
table1
# Out:
# pa3htkfrrlsr  1 YES  2 NO   All
# hc3brokebon1
# 1 YES            19    45    64
# 2 NO            397  3737  4134
# All             416  3782  4198

# %%
# Excluding Patients Prevented from Attending Religious Services by Health Before onset of Hip Fracture 

hip_fracture_study_pa3htkfrrlsr = hip_fracture_study[hip_fracture_study.pa3htkfrrlsr != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa3htkfrrlsr["hc4brokebon1"], 
                            columns=hip_fracture_study_pa3htkfrrlsr["pa4htkfrrlsr"],
                             margins=True)  
table1
# Out:
# pa4htkfrrlsr  1 YES  2 NO   All
# hc4brokebon1
# 1 YES             4    34    38
# 2 NO            354  3069  3423
# All             358  3103  3461

# %%
# Excluding Patients Prevented from Attending Religious Services by Health Before onset of Hip Fracture 

hip_fracture_study_pa4htkfrrlsr = hip_fracture_study[hip_fracture_study.pa4htkfrrlsr != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa4htkfrrlsr["hc5brokebon1"], 
                            columns=hip_fracture_study_pa4htkfrrlsr["pa5htkfrrlsr"],
                             margins=True)  
table1
# Out:
# pa5htkfrrlsr  1 YES  2 NO   All
# hc5brokebon1
# 1 YES            10    33    43
# 2 NO            271  2780  3051
# All             281  2813  3094

# %%
# Excluding Patients Prevented from Attending Clubs/Classes/Organized Activities by Health Before onset of Hip Fracture 

hip_fracture_study_pa1hlkpfrclb = hip_fracture_study[hip_fracture_study.pa1hlkpfrclb != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa1hlkpfrclb["hc2brokebon1"], 
                            columns=hip_fracture_study_pa1hlkpfrclb["pa2hlkpfrclb"],
                             margins=True)  
table1
# Out:
# pa2hlkpfrclb  1 YES  2 NO   All
# hc2brokebon1
# 1 YES            18    48    66
# 2 NO            397  4924  5321
# All             415  4972  5387

# %%
# Excluding Patients Prevented from Attending Clubs/Classes/Organized Activities by Health Before onset of Hip Fracture 

hip_fracture_study_pa2hlkpfrclb = hip_fracture_study[hip_fracture_study.pa2hlkpfrclb != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa2hlkpfrclb["hc3brokebon1"], 
                            columns=hip_fracture_study_pa2hlkpfrclb["pa3hlkpfrclb"],
                             margins=True)  
table1
# Out:
# pa3hlkpfrclb  1 YES  2 NO   All
# hc3brokebon1
# 1 YES            12    56    68
# 2 NO            380  3945  4325
# All             392  4001  4393

# %%
# Excluding Patients Prevented from Attending Clubs/Classes/Organized Activities by Health Before onset of Hip Fracture 

hip_fracture_study_pa3hlkpfrclb = hip_fracture_study[hip_fracture_study.pa3hlkpfrclb != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa3hlkpfrclb["hc4brokebon1"], 
                            columns=hip_fracture_study_pa3hlkpfrclb["pa4hlkpfrclb"],
                             margins=True)  
table1
# Out:
# pa4hlkpfrclb  1 YES  2 NO   All
# hc4brokebon1
# 1 YES             7    40    47
# 2 NO            294  3301  3595
# All             301  3341  3642

# %%
# Excluding Patients Prevented from Attending Clubs/Classes/Organized Activities by Health Before onset of Hip Fracture 

hip_fracture_study_pa4hlkpfrclb = hip_fracture_study[hip_fracture_study.pa4hlkpfrclb != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa4hlkpfrclb["hc5brokebon1"], 
                            columns=hip_fracture_study_pa4hlkpfrclb["pa5hlkpfrclb"],
                             margins=True)  
table1
# Out:
# pa5hlkpfrclb  1 YES  2 NO   All
# hc5brokebon1
# 1 YES             6    42    48
# 2 NO            284  2927  3211
# All             290  2969  3259

# %%
# Excluding Patients Prevented from Going out for Enjoyment by Health Before onset of Hip Fracture 

hip_fracture_study_pa1hlkpgoenj = hip_fracture_study[hip_fracture_study.pa1hlkpgoenj != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa1hlkpgoenj["hc2brokebon1"], 
                            columns=hip_fracture_study_pa1hlkpgoenj["pa2hlkpgoenj"],
                             margins=True)  
table1
# Out:
# pa2hlkpgoenj  1 YES  2 NO   All
# hc2brokebon1
# 1 YES            17    45    62
# 2 NO            421  4922  5343
# All             438  4967  5405

# %%
# Excluding Patients Prevented from Going out for Enjoyment by Health Before onset of Hip Fracture 

hip_fracture_study_pa2hlkpgoenj = hip_fracture_study[hip_fracture_study.pa2hlkpgoenj != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa2hlkpgoenj["hc3brokebon1"], 
                            columns=hip_fracture_study_pa2hlkpgoenj["pa3hlkpgoenj"],
                             margins=True)  
table1
# Out:
# pa3hlkpgoenj  1 YES  2 NO   All
# hc3brokebon1
# 1 YES            15    54    69
# 2 NO            357  3960  4317
# All             372  4014  4386

# %%
# Excluding Patients Prevented from Going out for Enjoyment by Health Before onset of Hip Fracture 

hip_fracture_study_pa3hlkpgoenj = hip_fracture_study[hip_fracture_study.pa3hlkpgoenj != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa1hlkpgoenj["hc4brokebon1"], 
                            columns=hip_fracture_study_pa1hlkpgoenj["pa4hlkpgoenj"],
                             margins=True)  
table1
# Out:
# pa4hlkpgoenj  1 YES  2 NO   All
# hc4brokebon1
# 1 YES            10    39    49
# 2 NO            313  3297  3610
# All             323  3336  3659

# %%
# Excluding Patients Prevented from Going out for Enjoyment by Health Before onset of Hip Fracture 

hip_fracture_study_pa4hlkpgoenj = hip_fracture_study[hip_fracture_study.pa4hlkpgoenj != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa4hlkpgoenj["hc5brokebon1"], 
                            columns=hip_fracture_study_pa4hlkpgoenj["pa5hlkpgoenj"],
                             margins=True)  
table1
# Out:
# pa5hlkpgoenj  1 YES  2 NO   All
# hc5brokebon1
# 1 YES             4    43    47
# 2 NO            239  3000  3239
# All             243  3043  3286

# %%
# Excluding Patients Prevented from Favorite Activity by Health Before onset of Hip Fracture 

hip_fracture_study_pa1helmfvact = hip_fracture_study[hip_fracture_study.pa1helmfvact != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa1helmfvact["hc2brokebon1"], 
                            columns=hip_fracture_study_pa1helmfvact["pa2helmfvact"],
                             margins=True)  
table1
# Out:
# pa2helmfvact  1 YES  2 NO  95 NO ACTIVITY LISTED   All
# hc2brokebon1
# 1 YES            23    39                      0    62
# 2 NO            763  4281                      5  5049
# All             786  4320                      5  5111

# %%
# Excluding Patients Prevented from Favorite Activity by Health Before onset of Hip Fracture 

hip_fracture_study_pa2helmfvact = hip_fracture_study[hip_fracture_study.pa2helmfvact != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa2helmfvact["hc3brokebon1"], 
                            columns=hip_fracture_study_pa2helmfvact["pa3helmfvact"],
                             margins=True)  
table1
# Out:
# pa3helmfvact  1 YES  2 NO   All
# hc3brokebon1
# 1 YES            30    33    63
# 2 NO            604  3105  3709
# All             634  3138  3772

# %%
# Excluding Patients Prevented from Favorite Activity by Health Before onset of Hip Fracture 

hip_fracture_study_pa3helmfvact = hip_fracture_study[hip_fracture_study.pa3helmfvact != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa3helmfvact["hc4brokebon1"], 
                            columns=hip_fracture_study_pa3helmfvact["pa4helmfvact"],
                             margins=True)  
table1
# Out:
# pa4helmfvact  1 YES  2 NO   All
# hc4brokebon1
# 1 YES            10    22    32
# 2 NO            481  2519  3000
# All             491  2541  3032

# %%
# Excluding Patients Prevented from Favorite Activity by Health Before onset of Hip Fracture 

hip_fracture_study_pa4helmfvact = hip_fracture_study[hip_fracture_study.pa4helmfvact != '1 YES']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_pa4helmfvact["hc5brokebon1"], 
                            columns=hip_fracture_study_pa4helmfvact["pa5helmfvact"],
                             margins=True)  
table1
# Out:
# pa5helmfvact  1 YES  2 NO   All
# hc5brokebon1
# 1 YES             7    27    34
# 2 NO            317  2466  2783
# All             324  2493  2817

# %%
# Excluding Patients Not Driving Before onset of Hip Fracture 

hip_fracture_study_dt1oftedrive = hip_fracture_study[hip_fracture_study.dt1oftedrive != '5 NEVER']
hip_fracture_study_dt1oftedrive = hip_fracture_study_dt1oftedrive[hip_fracture_study_dt1oftedrive.dt1oftedrive != '4 RARELY (ONCE A WEEK OR LESS)']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_dt1oftedrive["hc2brokebon1"], 
                            columns=hip_fracture_study_dt1oftedrive["dt2oftedrive"],
                             margins=True)  
table1
# Out:
# dt2oftedrive  1 EVERY DAY (7 DAYS A WEEK)  2 MOST DAYS (5-6 DAYS A WEEK)  \
# hc2brokebon1
# 1 YES                                   9                              5
# 2 NO                                 1713                           1241
# All                                  1722                           1246
#
# dt2oftedrive  3 SOME DAYS (2-4 DAYS A WEEK)  4 RARELY (ONCE A WEEK OR LESS)  \
# hc2brokebon1
# 1 YES                                     6                               2
# 2 NO                                    728                             112
# All                                     734                             114
#
# dt2oftedrive  5 NEVER   All
# hc2brokebon1
# 1 YES               6    28
# 2 NO               93  3887
# All                99  3915

# %%
# Excluding Patients Not Driving Before onset of Hip Fracture 

hip_fracture_study_dt2oftedrive = hip_fracture_study[hip_fracture_study.dt2oftedrive != '5 NEVER']
hip_fracture_study_dt2oftedrive = hip_fracture_study_dt2oftedrive[hip_fracture_study_dt2oftedrive.dt2oftedrive != '4 RARELY (ONCE A WEEK OR LESS)']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_dt2oftedrive["hc3brokebon1"], 
                            columns=hip_fracture_study_dt2oftedrive["dt3oftedrive"],
                             margins=True)  
table1
# Out:
# dt3oftedrive  1 EVERY DAY (7 DAYS A WEEK)  2 MOST DAYS (5-6 DAYS A WEEK)  \
# hc3brokebon1
# 1 YES                                   7                              8
# 2 NO                                 1310                           1024
# All                                  1317                           1032
#
# dt3oftedrive  3 SOME DAYS (2-4 DAYS A WEEK)  4 RARELY (ONCE A WEEK OR LESS)  \
# hc3brokebon1
# 1 YES                                    10                               2
# 2 NO                                    629                             121
# All                                     639                             123
#
# dt3oftedrive  5 NEVER   All
# hc3brokebon1
# 1 YES               3    30
# 2 NO              109  3193
# All               112  3223

# %%
# Excluding Patients Not Driving Before onset of Hip Fracture 

hip_fracture_study_dt3oftedrive = hip_fracture_study[hip_fracture_study.dt3oftedrive != '5 NEVER']
hip_fracture_study_dt3oftedrive = hip_fracture_study_dt3oftedrive[hip_fracture_study_dt3oftedrive.dt3oftedrive != '4 RARELY (ONCE A WEEK OR LESS)']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_dt3oftedrive["hc4brokebon1"], 
                            columns=hip_fracture_study_dt3oftedrive["dt4oftedrive"],
                             margins=True)  
table1
# Out:
# dt4oftedrive  1 EVERY DAY (7 DAYS A WEEK)  2 MOST DAYS (5-6 DAYS A WEEK)  \
# hc4brokebon1
# 1 YES                                   6                              8
# 2 NO                                 1068                            849
# All                                  1074                            857
#
# dt4oftedrive  3 SOME DAYS (2-4 DAYS A WEEK)  4 RARELY (ONCE A WEEK OR LESS)  \
# hc4brokebon1
# 1 YES                                     3                               1
# 2 NO                                    514                              84
# All                                     517                              85
#
# dt4oftedrive  5 NEVER   All
# hc4brokebon1
# 1 YES               4    22
# 2 NO               89  2604
# All                93  2626

# %%
# Excluding Patients Not Driving Before onset of Hip Fracture 

hip_fracture_study_dt4oftedrive = hip_fracture_study[hip_fracture_study.dt4oftedrive != '5 NEVER']
hip_fracture_study_dt4oftedrive = hip_fracture_study_dt4oftedrive[hip_fracture_study_dt4oftedrive.dt4oftedrive != '4 RARELY (ONCE A WEEK OR LESS)']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_dt4oftedrive["hc5brokebon1"], 
                            columns=hip_fracture_study_dt4oftedrive["dt5oftedrive"],
                             margins=True)  
table1
# Out:
# dt5oftedrive  1 EVERY DAY (7 DAYS A WEEK)  2 MOST DAYS (5-6 DAYS A WEEK)  \
# hc5brokebon1
# 1 YES                                   5                              3
# 2 NO                                  928                            774
# All                                   933                            777
#
# dt5oftedrive  3 SOME DAYS (2-4 DAYS A WEEK)  4 RARELY (ONCE A WEEK OR LESS)  \
# hc5brokebon1
# 1 YES                                     4                               1
# 2 NO                                    451                              90
# All                                     455                              91
#
# dt5oftedrive  5 NEVER   All
# hc5brokebon1
# 1 YES               5    18
# 2 NO               71  2314
# All                76  2332

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_mo1outoft = hip_fracture_study[hip_fracture_study.mo1outoft != '5 NEVER']
hip_fracture_study_mo1outoft = hip_fracture_study_mo1outoft[hip_fracture_study_mo1outoft.mo1outoft != '4 RARELY (ONCE A WEEK OR LESS)']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_mo1outoft["hc2brokebon1"], 
                            columns=hip_fracture_study_mo1outoft["mo2outoft"],
                             margins=True)  
table1
# Out:
# mo2outoft     1 EVERY DAY (7 DAYS A WEEK)  2 MOST DAYS (5-6 DAYS A WEEK)  \
# hc2brokebon1
# 1 YES                                  25                              7
# 2 NO                                 3736                            968
# All                                  3761                            975
#
# mo2outoft     3 SOME DAYS (2-4 DAYS A WEEK)  4 RARELY (ONCE A WEEK OR LESS)  \
# hc2brokebon1
# 1 YES                                    21                               7
# 2 NO                                    632                             220
# All                                     653                             227
#
# mo2outoft     5 NEVER   All
# hc2brokebon1
# 1 YES               6    66
# 2 NO               62  5618
# All                68  5684

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_mo2outoft = hip_fracture_study[hip_fracture_study.mo2outoft != '5 NEVER']
hip_fracture_study_mo2outoft = hip_fracture_study_mo2outoft[hip_fracture_study_mo2outoft.mo2outoft != '4 RARELY (ONCE A WEEK OR LESS)']

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_mo2outoft["hc3brokebon1"], 
                            columns=hip_fracture_study_mo2outoft["mo3outoft"],
                             margins=True)  
table1
# Out:
# mo3outoft     1 EVERY DAY (7 DAYS A WEEK)  2 MOST DAYS (5-6 DAYS A WEEK)  \
# hc3brokebon1
# 1 YES                                  23                             16
# 2 NO                                 2933                            789
# All                                  2956                            805
#
# mo3outoft     3 SOME DAYS (2-4 DAYS A WEEK)  4 RARELY (ONCE A WEEK OR LESS)  \
# hc3brokebon1
# 1 YES                                    15                              11
# 2 NO                                    542                             179
# All                                     557                             190
#
# mo3outoft     5 NEVER   All
# hc3brokebon1
# 1 YES               2    67
# 2 NO               45  4488
# All                47  4555

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_mo3outoft = hip_fracture_study[hip_fracture_study.mo3outoft != '5 NEVER']
hip_fracture_study_mo3outoft = hip_fracture_study_mo3outoft[hip_fracture_study_mo3outoft.mo3outoft != '4 RARELY (ONCE A WEEK OR LESS)']


# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_mo3outoft["hc4brokebon1"], 
                            columns=hip_fracture_study_mo3outoft["mo4outoft"],
                             margins=True)  
table1
# Out:
# mo4outoft     1 EVERY DAY (7 DAYS A WEEK)  2 MOST DAYS (5-6 DAYS A WEEK)  \
# hc4brokebon1
# 1 YES                                  16                              8
# 2 NO                                 2348                            714
# All                                  2364                            722
#
# mo4outoft     3 SOME DAYS (2-4 DAYS A WEEK)  4 RARELY (ONCE A WEEK OR LESS)  \
# hc4brokebon1
# 1 YES                                    11                               7
# 2 NO                                    487                             159
# All                                     498                             166
#
# mo4outoft     5 NEVER   All
# hc4brokebon1
# 1 YES               2    44
# 2 NO               30  3738
# All                32  3782

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_mo4outoft = hip_fracture_study[hip_fracture_study.mo4outoft != '5 NEVER']
hip_fracture_study_mo4outoft = hip_fracture_study_mo4outoft[hip_fracture_study_mo4outoft.mo4outoft != '4 RARELY (ONCE A WEEK OR LESS)']


# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_mo4outoft["hc5brokebon1"], 
                            columns=hip_fracture_study_mo4outoft["mo5outoft"],
                             margins=True)  
table1
# Out:
# mo5outoft     1 EVERY DAY (7 DAYS A WEEK)  2 MOST DAYS (5-6 DAYS A WEEK)  \
# hc5brokebon1
# 1 YES                                  19                             10
# 2 NO                                 2038                            680
# All                                  2057                            690
#
# mo5outoft     3 SOME DAYS (2-4 DAYS A WEEK)  4 RARELY (ONCE A WEEK OR LESS)  \
# hc5brokebon1
# 1 YES                                    13                               3
# 2 NO                                    446                             146
# All                                     459                             149
#
# mo5outoft     5 NEVER   All
# hc5brokebon1
# 1 YES               2    47
# 2 NO               25  3335
# All                27  3382

# %%
# Creating a Variable Representing "Working Status" - If Patients Work for Pay or Volunteer HKF_Work_Vol = 1 else HKF_Work_Vol = 0

conditions = [(hip_fracture_study['pa2workfrpay'] == '1 YES'), (hip_fracture_study['pa2workfrpay'] == '2 NO')]
choices = [1, 0]
hip_fracture_study['pa2workfrpay'] = np.select(conditions, choices)

conditions = [(hip_fracture_study['pa2voltrwork'] == '1 YES') , (hip_fracture_study['pa2voltrwork'] == '2 NO')]
choices = [1, 0]
hip_fracture_study['pa2voltrwork'] = np.select(conditions, choices)

hip_fracture_study['HKF_Work_VolR2'] = hip_fracture_study['pa2voltrwork']+hip_fracture_study['pa2workfrpay']
                                                                                                             
conditions = [(hip_fracture_study['HKF_Work_VolR2'] >= 1),(hip_fracture_study['HKF_Work_VolR2'] == 0)]
choices = [1, 0]
hip_fracture_study['HKF_Work_VolR2'] = np.select(conditions, choices)

# %%
# Creating a Variable Representing "Working Status" - If Patients Work for Pay or Volunteer HKF_Work_Vol = 1 else HKF_Work_Vol = 0

conditions = [(hip_fracture_study['pa3workfrpay'] == '1 YES'), (hip_fracture_study['pa3workfrpay'] == '2 NO')]
choices = [1, 0]
hip_fracture_study['pa3workfrpay'] = np.select(conditions, choices)

conditions = [(hip_fracture_study['pa3voltrwork'] == '1 YES') , (hip_fracture_study['pa3voltrwork'] == '2 NO')]
choices = [1, 0]
hip_fracture_study['pa3voltrwork'] = np.select(conditions, choices)

hip_fracture_study['HKF_Work_VolR3'] = hip_fracture_study['pa3voltrwork']+hip_fracture_study['pa3workfrpay']
                                                                                                             
conditions = [(hip_fracture_study['HKF_Work_VolR3'] >= 1),(hip_fracture_study['HKF_Work_VolR3'] == 0)]
choices = [1, 0]
hip_fracture_study['HKF_Work_VolR3'] = np.select(conditions, choices)

# %%
# Creating a Variable Representing "Working Status" - If Patients Work for Pay or Volunteer HKF_Work_Vol = 1 else HKF_Work_Vol = 0

conditions = [(hip_fracture_study['pa4workfrpay'] == '1 YES'), (hip_fracture_study['pa4workfrpay'] == '2 NO')]
choices = [1, 0]
hip_fracture_study['pa4workfrpay'] = np.select(conditions, choices)

conditions = [(hip_fracture_study['pa4voltrwork'] == '1 YES') , (hip_fracture_study['pa4voltrwork'] == '2 NO')]
choices = [1, 0]
hip_fracture_study['pa4voltrwork'] = np.select(conditions, choices)

hip_fracture_study['HKF_Work_VolR4'] = hip_fracture_study['pa4voltrwork']+hip_fracture_study['pa4workfrpay']
                                                                                                             
conditions = [(hip_fracture_study['HKF_Work_VolR4'] >= 1),(hip_fracture_study['HKF_Work_VolR4'] == 0)]
choices = [1, 0]
hip_fracture_study['HKF_Work_VolR4'] = np.select(conditions, choices)

# %%
# Creating a Variable Representing "Working Status" - If Patients Work for Pay or Volunteer HKF_Work_Vol = 1 else HKF_Work_Vol = 0

conditions = [(hip_fracture_study['pa5workfrpay'] == '1 YES'), (hip_fracture_study['pa5workfrpay'] == '2 NO')]
choices = [1, 0]
hip_fracture_study['pa5workfrpay'] = np.select(conditions, choices)

conditions = [(hip_fracture_study['pa5voltrwork'] == '1 YES') , (hip_fracture_study['pa5voltrwork'] == '2 NO')]
choices = [1, 0]
hip_fracture_study['pa5voltrwork'] = np.select(conditions, choices)

hip_fracture_study['HKF_Work_VolR5'] = hip_fracture_study['pa5voltrwork']+hip_fracture_study['pa5workfrpay']
                                                                                                             
conditions = [(hip_fracture_study['HKF_Work_VolR5'] >= 1),(hip_fracture_study['HKF_Work_VolR5'] == 0)]
choices = [1, 0]
hip_fracture_study['HKF_Work_VolR5'] = np.select(conditions, choices)

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_HKF_Work_Vol = hip_fracture_study[hip_fracture_study.HKF_Work_Vol != 0]

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_HKF_Work_Vol["hc2brokebon1"], 
                            columns=hip_fracture_study_HKF_Work_Vol["HKF_Work_VolR2"],
                             margins=True)  
table1
# Out:
# HKF_Work_VolR2    0     1   All
# hc2brokebon1
# 1 YES             7     3    10
# 2 NO            577  1489  2066
# All             584  1492  2076

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_HKF_Work_VolR2 = hip_fracture_study[hip_fracture_study.HKF_Work_VolR2 != 0]

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_HKF_Work_VolR2["hc3brokebon1"], 
                            columns=hip_fracture_study_HKF_Work_VolR2["HKF_Work_VolR3"],
                             margins=True)  
table1
# Out:
# HKF_Work_VolR3    0     1   All
# hc3brokebon1
# 1 YES             6    10    16
# 2 NO            421  1213  1634
# All             427  1223  1650

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_HKF_Work_VolR3 = hip_fracture_study[hip_fracture_study.HKF_Work_VolR3 != 0]

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_HKF_Work_VolR3["hc4brokebon1"], 
                            columns=hip_fracture_study_HKF_Work_VolR3["HKF_Work_VolR4"],
                             margins=True)  
table1
# Out:
# HKF_Work_VolR4    0     1   All
# hc4brokebon1
# 1 YES             4     9    13
# 2 NO            343  1007  1350
# All             347  1016  1363

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_HKF_Work_VolR4 = hip_fracture_study[hip_fracture_study.HKF_Work_VolR4 != 0]

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_HKF_Work_VolR4["hc5brokebon1"], 
                            columns=hip_fracture_study_HKF_Work_VolR4["HKF_Work_VolR5"],
                             margins=True)  
table1
# Out:
# HKF_Work_VolR5    0    1   All
# hc5brokebon1
# 1 YES             4    5     9
# 2 NO            291  915  1206
# All             295  920  1215

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_HKF_Work_VolR3 = hip_fracture_study[hip_fracture_study.HKF_Work_VolR3 != 0]

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_HKF_Work_VolR3["hc4brokebon1"], 
                            columns=hip_fracture_study_HKF_Work_VolR3["HKF_Work_VolR4"],
                             margins=True)  
table1
# Out:
# HKF_Work_VolR4    0     1   All
# hc4brokebon1
# 1 YES             4     9    13
# 2 NO            343  1007  1350
# All             347  1016  1363

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_ew1medpaovtm = hip_fracture_study[hip_fracture_study.ew1medpaovtm != 0]

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_ew1medpaovtm["hc2brokebon1"], 
                            columns=hip_fracture_study_ew1medpaovtm["ew2medpaovtm"],
                             margins=True)  
table1
# Out:
# ew2medpaovtm  1 YES  2 NO   All
# hc2brokebon1
# 1 YES            10    64    74
# 2 NO            511  5372  5883
# All             521  5436  5957

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_ew2medpaovtm = hip_fracture_study[hip_fracture_study.ew2medpaovtm != 0]

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_ew2medpaovtm["hc3brokebon1"], 
                            columns=hip_fracture_study_ew2medpaovtm["ew3medpaovtm"],
                             margins=True)  
table1
# Out:
# ew3medpaovtm  1 YES  2 NO   All
# hc3brokebon1
# 1 YES            16    67    83
# 2 NO            433  4181  4614
# All             449  4248  4697

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_ew3medpaovtm = hip_fracture_study[hip_fracture_study.ew3medpaovtm != 0]

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_ew3medpaovtm["hc4brokebon1"], 
                            columns=hip_fracture_study_ew3medpaovtm["ew4medpaovtm"],
                             margins=True)  
table1
# Out:
# ew4medpaovtm  1 YES  2 NO   All
# hc4brokebon1
# 1 YES            10    43    53
# 2 NO            340  3467  3807
# All             350  3510  3860

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_ew4medpaovtm = hip_fracture_study[hip_fracture_study.ew4medpaovtm != 0]

# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_ew4medpaovtm["hc5brokebon1"], 
                            columns=hip_fracture_study_ew4medpaovtm["ew5medpaovtm"],
                             margins=True)  
table1
# Out:
# ew5medpaovtm  1 YES  2 NO   All
# hc5brokebon1
# 1 YES             4    46    50
# 2 NO            325  3143  3468
# All             329  3189  3518

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc1depresan1 = hip_fracture_study[hip_fracture_study.hc1depresan1 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc1depresan1 = hip_fracture_study_hc1depresan1[hip_fracture_study_hc1depresan1.hc1depresan1 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc1depresan1["hc2brokebon1"], 
                            columns=hip_fracture_study_hc1depresan1["hc2depresan1"],
                             margins=True)  
table1
# Out:
# hc2depresan1  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc2brokebon1
# 1 YES                   33               9                          8
# 2 NO                  3417            1072                        299
# All                   3450            1081                        307
#
# hc2depresan1  4 NEARLY EVERY DAY   All
# hc2brokebon1
# 1 YES                         12    62
# 2 NO                         259  5047
# All                          271  5109

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc2depresan1 = hip_fracture_study[hip_fracture_study.hc2depresan1 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc2depresan1 = hip_fracture_study_hc2depresan1[hip_fracture_study_hc2depresan1.hc2depresan1 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc2depresan1["hc3brokebon1"], 
                            columns=hip_fracture_study_hc2depresan1["hc3depresan1"],
                             margins=True)  
table1
# Out:
# hc3depresan1  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc3brokebon1
# 1 YES                   33              18                          5
# 2 NO                  2807             872                        230
# All                   2840             890                        235
#
# hc3depresan1  4 NEARLY EVERY DAY   All
# hc3brokebon1
# 1 YES                         13    69
# 2 NO                         233  4142
# All                          246  4211

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc3depresan1 = hip_fracture_study[hip_fracture_study.hc3depresan1 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc3depresan1 = hip_fracture_study_hc3depresan1[hip_fracture_study_hc3depresan1.hc3depresan1 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc3depresan1["hc4brokebon1"], 
                            columns=hip_fracture_study_hc3depresan1["hc4depresan1"],
                             margins=True)  
table1
# Out:
# hc4depresan1  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc4brokebon1
# 1 YES                   24               7                          8
# 2 NO                  2305             755                        195
# All                   2329             762                        203
#
# hc4depresan1  4 NEARLY EVERY DAY   All
# hc4brokebon1
# 1 YES                          2    41
# 2 NO                         185  3440
# All                          187  3481

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc4depresan1 = hip_fracture_study[hip_fracture_study.hc4depresan1 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc4depresan1 = hip_fracture_study_hc4depresan1[hip_fracture_study_hc4depresan1.hc4depresan1 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc4depresan1["hc5brokebon1"], 
                            columns=hip_fracture_study_hc4depresan1["hc5depresan1"],
                             margins=True)  
table1
# Out:
# hc5depresan1  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc5brokebon1
# 1 YES                   26               5                          5
# 2 NO                  2054             691                        184
# All                   2080             696                        189
#
# hc5depresan1  4 NEARLY EVERY DAY   All
# hc5brokebon1
# 1 YES                          7    43
# 2 NO                         141  3070
# All                          148  3113

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc1depresan2 = hip_fracture_study[hip_fracture_study.hc1depresan2 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc1depresan2 = hip_fracture_study_hc1depresan2[hip_fracture_study_hc1depresan2.hc1depresan2 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc1depresan2["hc2brokebon1"], 
                            columns=hip_fracture_study_hc1depresan2["hc2depresan2"],
                             margins=True)  
table1
# Out:
# hc2depresan2  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc2brokebon1
# 1 YES                   37              16                          6
# 2 NO                  4105            1055                        192
# All                   4142            1071                        198
#
# hc2depresan2  4 NEARLY EVERY DAY   All
# hc2brokebon1
# 1 YES                          3    62
# 2 NO                         123  5475
# All                          126  5537

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc2depresan2 = hip_fracture_study[hip_fracture_study.hc2depresan2 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc2depresan2 = hip_fracture_study_hc2depresan2[hip_fracture_study_hc2depresan2.hc2depresan2 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc2depresan2["hc3brokebon1"], 
                            columns=hip_fracture_study_hc2depresan2["hc3depresan2"],
                             margins=True)  
table1
# Out:
# hc3depresan2  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc3brokebon1
# 1 YES                   47              17                          4
# 2 NO                  3302             865                        141
# All                   3349             882                        145
#
# hc3depresan2  4 NEARLY EVERY DAY   All
# hc3brokebon1
# 1 YES                          9    77
# 2 NO                         117  4425
# All                          126  4502

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc3depresan2 = hip_fracture_study[hip_fracture_study.hc3depresan2 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc3depresan2 = hip_fracture_study_hc3depresan2[hip_fracture_study_hc3depresan2.hc3depresan2 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc3depresan2["hc4brokebon1"], 
                            columns=hip_fracture_study_hc3depresan2["hc4depresan2"],
                             margins=True)  
table1
# Out:
# hc4depresan2  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc4brokebon1
# 1 YES                   27              12                          4
# 2 NO                  2719             752                        118
# All                   2746             764                        122
#
# hc4depresan2  4 NEARLY EVERY DAY   All
# hc4brokebon1
# 1 YES                          3    46
# 2 NO                          78  3667
# All                           81  3713

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc4depresan2 = hip_fracture_study[hip_fracture_study.hc4depresan2 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc4depresan2 = hip_fracture_study_hc4depresan2[hip_fracture_study_hc4depresan2.hc4depresan2 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc4depresan2["hc5brokebon1"], 
                            columns=hip_fracture_study_hc4depresan2["hc5depresan2"],
                             margins=True)  
table1
# Out:
# hc5depresan2  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc5brokebon1
# 1 YES                   30              13                          3
# 2 NO                  2478             685                         97
# All                   2508             698                        100
#
# hc5depresan2  4 NEARLY EVERY DAY   All
# hc5brokebon1
# 1 YES                          2    48
# 2 NO                          65  3325
# All                           67  3373

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc1depresan3 = hip_fracture_study[hip_fracture_study.hc1depresan3 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc1depresan3 = hip_fracture_study_hc1depresan3[hip_fracture_study_hc1depresan3.hc1depresan3 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc1depresan3["hc2brokebon1"], 
                            columns=hip_fracture_study_hc1depresan3["hc2depresan3"],
                             margins=True)  
table1
# Out:
# hc2depresan3  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc2brokebon1
# 1 YES                   37              16                          5
# 2 NO                  3743            1377                        178
# All                   3780            1393                        183
#
# hc2depresan3  4 NEARLY EVERY DAY   All
# hc2brokebon1
# 1 YES                          6    64
# 2 NO                         130  5428
# All                          136  5492

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc2depresan3 = hip_fracture_study[hip_fracture_study.hc2depresan3 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc2depresan3 = hip_fracture_study_hc2depresan3[hip_fracture_study_hc2depresan3.hc2depresan3 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc2depresan3["hc3brokebon1"], 
                            columns=hip_fracture_study_hc2depresan3["hc3depresan3"],
                             margins=True)  
table1
# Out:
# hc3depresan3  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc3brokebon1
# 1 YES                   39              28                          5
# 2 NO                  2971            1154                        141
# All                   3010            1182                        146
#
# hc3depresan3  4 NEARLY EVERY DAY   All
# hc3brokebon1
# 1 YES                          5    77
# 2 NO                         129  4395
# All                          134  4472

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc3depresan3 = hip_fracture_study[hip_fracture_study.hc3depresan3 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc3depresan3 = hip_fracture_study_hc3depresan3[hip_fracture_study_hc3depresan3.hc3depresan3 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc3depresan3["hc4brokebon1"], 
                            columns=hip_fracture_study_hc3depresan3["hc4depresan3"],
                             margins=True)  
table1
# Out:
# hc4depresan3  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc4brokebon1
# 1 YES                   25              18                          2
# 2 NO                  2507             955                        107
# All                   2532             973                        109
#
# hc4depresan3  4 NEARLY EVERY DAY   All
# hc4brokebon1
# 1 YES                          5    50
# 2 NO                          94  3663
# All                           99  3713

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc4depresan3 = hip_fracture_study[hip_fracture_study.hc4depresan3 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc4depresan3 = hip_fracture_study_hc4depresan3[hip_fracture_study_hc4depresan3.hc4depresan3 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc4depresan3["hc5brokebon1"], 
                            columns=hip_fracture_study_hc4depresan3["hc5depresan3"],
                             margins=True)  
table1
# Out:
# hc5depresan3  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc5brokebon1
# 1 YES                   32              10                          4
# 2 NO                  2300             813                        117
# All                   2332             823                        121
#
# hc5depresan3  4 NEARLY EVERY DAY   All
# hc5brokebon1
# 1 YES                          2    48
# 2 NO                          72  3302
# All                           74  3350

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc1depresan4 = hip_fracture_study[hip_fracture_study.hc1depresan4 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc1depresan4 = hip_fracture_study_hc1depresan4[hip_fracture_study_hc1depresan4.hc1depresan4 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc1depresan4["hc2brokebon1"], 
                            columns=hip_fracture_study_hc1depresan4["hc2depresan4"],
                             margins=True)  
table1
# Out:
# hc2depresan4  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc2brokebon1
# 1 YES                   38              19                          7
# 2 NO                  4089             824                        178
# All                   4127             843                        185
#
# hc2depresan4  4 NEARLY EVERY DAY   All
# hc2brokebon1
# 1 YES                          6    70
# 2 NO                         221  5312
# All                          227  5382

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc2depresan4 = hip_fracture_study[hip_fracture_study.hc2depresan4 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc2depresan4 = hip_fracture_study_hc2depresan4[hip_fracture_study_hc2depresan4.hc2depresan4 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc2depresan4["hc3brokebon1"], 
                            columns=hip_fracture_study_hc2depresan4["hc3depresan4"],
                             margins=True)  
table1
# Out:
# hc3depresan4  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc3brokebon1
# 1 YES                   45              16                          6
# 2 NO                  3375             653                        122
# All                   3420             669                        128
#
# hc3depresan4  4 NEARLY EVERY DAY   All
# hc3brokebon1
# 1 YES                          3    70
# 2 NO                         173  4323
# All                          176  4393

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc3depresan4 = hip_fracture_study[hip_fracture_study.hc3depresan4 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc3depresan4 = hip_fracture_study_hc3depresan4[hip_fracture_study_hc3depresan4.hc3depresan4 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc3depresan4["hc4brokebon1"], 
                            columns=hip_fracture_study_hc3depresan4["hc4depresan4"],
                             margins=True)  
table1
# Out:
# hc4depresan4  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc4brokebon1
# 1 YES                   34              10                          1
# 2 NO                  2753             601                        107
# All                   2787             611                        108
#
# hc4depresan4  4 NEARLY EVERY DAY   All
# hc4brokebon1
# 1 YES                          0    45
# 2 NO                         136  3597
# All                          136  3642

# %%
# Excluding Patients Not Mobile Before onset of Hip Fracture 

hip_fracture_study_hc4depresan4 = hip_fracture_study[hip_fracture_study.hc4depresan4 != '4 NEARLY EVERY DAY']
hip_fracture_study_hc4depresan4 = hip_fracture_study_hc4depresan4[hip_fracture_study_hc4depresan4.hc4depresan4 != '3 MORE THAN HALF THE DAYS']
# Frequency tables - Activity Analysis - NOT FOR INCOME 

table1 = pd.crosstab(index=hip_fracture_study_hc4depresan4["hc5brokebon1"], 
                            columns=hip_fracture_study_hc4depresan4["hc5depresan4"],
                             margins=True)  
table1
# Out:
# hc5depresan4  1 NOT AT ALL  2 SEVERAL DAYS  3 MORE THAN HALF THE DAYS  \
# hc5brokebon1
# 1 YES                   33               6                          3
# 2 NO                  2487             565                        104
# All                   2520             571                        107
#
# hc5depresan4  4 NEARLY EVERY DAY   All
# hc5brokebon1
# 1 YES                          7    49
# 2 NO                          97  3253
# All                          104  3302

# %%
hip_fracture_study.groupby('hc2brokebon1').mean()
# Out:
#                       spid  is1dproxyid  pa1workfrpay  pa1voltrwork  \
# hc2brokebon1
# 1 YES         1.000611e+07          2.0      0.064103      0.076923
# 2 NO          1.000625e+07          2.0      0.152108      0.248327
#
#               ab1datemonth  ab1dateyear  in1strtabhrs  in1strtabmin  \
# hc2brokebon1
# 1 YES             4.666667  1829.717949      5.589744     22.410256
# 2 NO              5.311412  1884.580991      5.198126     25.053380
#
#               ia1vajtest   ia1toincim1       ...        w7varstrat  w7varunit  \
# hc2brokebon1                                 ...
# 1 YES                NaN  27416.461538       ...         27.878788   1.393939
# 2 NO                 NaN  49575.745147       ...         23.787879   1.490714
#
#               HKF_Work_Vol  R1avg_income1-5  R3avg_income1-5   changeR1R3  \
# hc2brokebon1
# 1 YES             0.128205     31264.284615     27907.475000 -4231.093750
# ...

# %%
hip_fracture_study.groupby('hc3brokebon1').mean()
# Out:
#                       spid  is1dproxyid  pa1workfrpay  pa1voltrwork  \
# hc3brokebon1
# 1 YES         1.000601e+07          2.0      0.058140      0.116279
# 2 NO          1.000622e+07          2.0      0.160584      0.263191
#
#               ab1datemonth  ab1dateyear  in1strtabhrs  in1strtabmin  \
# hc3brokebon1
# 1 YES             4.546512  1823.093023      4.313953     27.325581
# 2 NO              5.434619  1902.733055      5.398749     25.303650
#
#               ia1vajtest   ia1toincim1       ...        w7varstrat  w7varunit  \
# hc3brokebon1                                 ...
# 1 YES                NaN  30790.476744       ...         24.675000   1.525000
# 2 NO                 NaN  52208.329093       ...         23.846809   1.489689
#
#               HKF_Work_Vol  R1avg_income1-5  R3avg_income1-5    changeR1R3  \
# hc3brokebon1
# 1 YES             0.174419     37475.383721     35628.911111  10864.337778
# ...

# %%
hip_fracture_study.groupby('hc4brokebon1').mean()
# Out:
#                       spid  is1dproxyid  pa1workfrpay  pa1voltrwork  \
# hc4brokebon1
# 1 YES         1.000637e+07          2.0      0.122807      0.210526
# 2 NO          1.000619e+07          2.0      0.166625      0.276200
#
#               ab1datemonth  ab1dateyear  in1strtabhrs  in1strtabmin  \
# hc4brokebon1
# 1 YES             4.824561  1833.807018      6.000000     24.719298
# 2 NO              5.530284  1915.558934      5.432521     25.465695
#
#               ia1vajtest   ia1toincim1       ...        w7varstrat  w7varunit  \
# hc4brokebon1                                 ...
# 1 YES                NaN  28453.894737       ...         24.272727   1.484848
# 2 NO                 NaN  54375.910530       ...         23.871433   1.488685
#
#               HKF_Work_Vol  R1avg_income1-5  R3avg_income1-5   changeR1R3  \
# hc4brokebon1
# 1 YES             0.298246     29308.852632     26824.964286   578.071429
# ...

# %%
hip_fracture_study.groupby('hc5brokebon1').mean()
# Out:
#                       spid  is1dproxyid  pa1workfrpay  pa1voltrwork  \
# hc5brokebon1
# 1 YES         1.000670e+07          2.0      0.054545      0.218182
# 2 NO          1.000623e+07          2.0      0.175861      0.281994
#
#               ab1datemonth  ab1dateyear  in1strtabhrs  in1strtabmin  \
# hc5brokebon1
# 1 YES             5.036364  1864.090909      4.727273     25.854545
# 2 NO              5.585550  1923.321479      5.525623     25.627835
#
#               ia1vajtest   ia1toincim1       ...        w7varstrat  w7varunit  \
# hc5brokebon1                                 ...
# 1 YES                NaN  32745.036364       ...         25.871795   1.512821
# 2 NO                 NaN  56502.276673       ...         23.859029   1.489270
#
#               HKF_Work_Vol  R1avg_income1-5  R3avg_income1-5   changeR1R3  \
# hc5brokebon1
# 1 YES             0.236364     32430.116364     30209.962963 -4297.570370
# ...

# %%
hip_fracture_study.groupby('hc6brokebon1').mean()
# Out:
#                       spid  is1dproxyid  pa1workfrpay  pa1voltrwork  \
# hc6brokebon1
# 1 YES         1.000637e+07          2.0      0.053571      0.178571
# 2 NO          1.000620e+07          2.0      0.186054      0.297940
#
#               ab1datemonth  ab1dateyear  in1strtabhrs  in1strtabmin  \
# hc6brokebon1
# 1 YES             4.214286  1722.428571      3.517857     20.714286
# 2 NO              5.628209  1932.248811      5.575277     25.943899
#
#               ia1vajtest   ia1toincim1       ...        w7varstrat  w7varunit  \
# hc6brokebon1                                 ...
# 1 YES                NaN  34252.446429       ...         27.372549   1.490196
# 2 NO                 NaN  58839.019968       ...         23.846538   1.489015
#
#               HKF_Work_Vol  R1avg_income1-5  R3avg_income1-5   changeR1R3  \
# hc6brokebon1
# 1 YES             0.214286     49493.525000     30444.826087 -1897.704348
# ...
